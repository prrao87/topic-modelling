# %%
import sys
import time
from math import sqrt, ceil
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.types import StructType, StructField, StringType, DateType
from pyspark.ml.feature import CountVectorizer, HashingTF, IDF, Tokenizer
from pyspark.ml.clustering import LDA, LDAModel
#Spark NLP
from sparknlp.annotator import *
from sparknlp.base import *
# plotting
from matplotlib import pyplot as plt
from wordcloud import WordCloud
import matplotlib.colors as mcolors

# %%
spark = SparkSession.builder \
                    .appName("TopicModel") \
                    .config("spark.jars.packages",
                            "JohnSnowLabs:spark-nlp:2.3.4") \
                    .getOrCreate()
sc = spark.sparkContext

# %%
print("Apache Spark version: ", spark.version)
# Out:
# Apache Spark version:  2.4.0

# %%
# define schema for data
schema = StructType([
    StructField("date", DateType(), True),
    StructField("headline", StringType(), True),
    StructField("content", StringType(), True)])

# %%
df = spark.read \
          .option("header", "false") \
          .csv("../data/nytimes.tsv", sep='\t', schema=schema) \
          .toDF("date", "headline", "content") \
          .drop("headline")
df.show(5)
# Out:
# +----------+--------------------+
# |      date|             content|
# +----------+--------------------+
# |2016-06-30|Stellar pitching ...|
# |2016-06-30|Mayor Bill de Bla...|
# |2016-06-30|In the early morn...|
# |2016-06-30|It was the Apple ...|
# |2016-06-30|The United States...|
# +----------+--------------------+
# only showing top 5 rows

# %% [markdown]
# #### (Optional) Run tests on a subset of the full data

# %%
df1 = df.limit(2000)

# %% [markdown]
# ### Spark NLP pipeline

# %%
document_assembler = DocumentAssembler() \
    .setInputCol("content")

sentence_detector = SentenceDetector() \
    .setInputCols(["document"]) \
    .setOutputCol("sentence")

tokenizer = Tokenizer() \
    .setInputCols(["sentence"]) \
    .setOutputCol("token")

normalizer = Normalizer() \
    .setInputCols(["token"]) \
    .setOutputCol("normalized") \
    .setLowercase(True) 

# Read in a custom stopword list (vetted by experts if possible)
stopwords = sc.textFile("stopwords/custom_stopwords.txt").collect()
stopWordsCleaner = StopWordsCleaner() \
      .setInputCols("normalized") \
      .setOutputCol("cleanTokens") \
      .setStopWords(stopwords) \
      .setCaseSensitive(False)

# Use default pretrained lemmatizer dictionary for now
lemmatizer = LemmatizerModel.pretrained(name="lemma_antbnc", lang="en") \
    .setInputCols(["cleanTokens"]) \
    .setOutputCol("lemma") \

finisher = Finisher() \
    .setInputCols(["lemma"]) \
    .setIncludeMetadata(False)

nlpPipeline = Pipeline(stages=[
    document_assembler, 
    sentence_detector, 
    tokenizer,
    normalizer,
    stopWordsCleaner,
    lemmatizer,
    finisher
])
# Out:
# lemma_antbnc download started this may take some time.
# Approximate size to download 907.6 KB
# [OK!]

# %%
nlpPipelineDF = nlpPipeline.fit(df1) \
                .transform(df1) \
                .withColumnRenamed('finished_lemma', 'text')
nlpPipelineDF.show(5)
# Out:
# +----------+--------------------+--------------------+
# |      date|             content|                text|
# +----------+--------------------+--------------------+
# |2016-06-30|Stellar pitching ...|[stellar, pitch, ...|
# |2016-06-30|Mayor Bill de Bla...|[mayor, bill, bla...|
# |2016-06-30|In the early morn...|[early, morning, ...|
# |2016-06-30|It was the Apple ...|[apple, store, ne...|
# |2016-06-30|The United States...|[united, state, o...|
# +----------+--------------------+--------------------+
# only showing top 5 rows

# %%
nlpPipelineDF.count()
# Out:
# 2000

# %% [markdown]
# ### Spark ML pipeline

# %%
cv = CountVectorizer(inputCol="text",
                     outputCol="features",
                     vocabSize=3000,
                     minDF=0.02,
                     maxDF=0.5,
                     minTF=2.0)
idf = IDF(inputCol="features", outputCol="idf")

num_topics = 10
lda = LDA(k=num_topics,
          maxIter=10, 
          optimizer="online",
          seed=1,
          learningOffset=100.0,  # If high, early iterations are downweighted during training
          learningDecay=0.51,    # Set between [0.5, 1) to guarantee asymptotic convergence
         )

# Create Spark-NLP Pipeline
mlPipeline = Pipeline(stages=[
    cv,
    idf,
    lda
])

# %% [markdown]
# #### Train Spark ML pipeline using Spark-NLP pipeline

# %%
mlModel = mlPipeline.fit(nlpPipelineDF)
mlPipelineDF = mlModel.transform(nlpPipelineDF)
mlPipelineDF.show(5)
# Out:
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |      date|             content|                text|            features|                 idf|   topicDistribution|
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+
# |2016-06-30|Stellar pitching ...|[stellar, pitch, ...|(2513,[2,5,9,12,2...|(2513,[2,5,9,12,2...|[6.42691599843490...|
# |2016-06-30|Mayor Bill de Bla...|[mayor, bill, bla...|(2513,[11,27,31,7...|(2513,[11,27,31,7...|[0.00117871158702...|
# |2016-06-30|In the early morn...|[early, morning, ...|(2513,[5,7,11,25,...|(2513,[5,7,11,25,...|[0.07671951593073...|
# |2016-06-30|It was the Apple ...|[apple, store, ne...|(2513,[0,1,2,6,11...|(2513,[0,1,2,6,11...|[8.35114536373807...|
# |2016-06-30|The United States...|[united, state, o...|(2513,[6,7,10,12,...|(2513,[6,7,10,12,...|[7.21423490187446...|
# +----------+--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %% [markdown]
# #### Evaluate LDA model

# %%
ldaModel = mlModel.stages[2]

# %%
ll = ldaModel.logLikelihood(mlPipelineDF)
lp = ldaModel.logPerplexity(mlPipelineDF)
print("Lower bound on log likelihood of the corpus: " + str(ll))
print("Upper bound on perplexity: " + str(lp))
# Out:
# Lower bound on log likelihood of the corpus: -2146049.5562662287
# Upper bound on perplexity: 6.9516008599126975

# %% [markdown]
# ### Show top-n keywords for each topic

# %%
# Take top 15 words in each topic
topics = ldaModel.describeTopics(15)
topics_rdd = topics.rdd

vocab = mlModel.stages[0].vocabulary  # Vocab from countVectorizer

topic_words = topics_rdd \
        .map(lambda row: row['termIndices']) \
        .map(lambda idx_list: [vocab[idx] for idx in idx_list]) \
        .collect()

topic_weights = topics_rdd \
        .map(lambda row: row['termWeights']) \
        .collect()

for i, topic in enumerate(topic_words):
    words = ', '.join([word for word in topic])
    print("topic {}: {}".format(i + 1, words))
    print('-------------')
# Out:
# topic 1: school, student, know, work, family, gun, law, write, college, tell, lawyer, think, friend, home, book
# -------------
# topic 2: water, human, animal, flight, test, climate, film, review, movie, round, change, report, build, wind, cause
# -------------
# topic 3: park, increase, driver, car, drive, good, disney, average, group, city, open, insurance, percent, service, company
# -------------
# topic 4: trump, european, britain, vote, campaign, union, republican, clinton, party, bank, leave, europe, market, economic, political
# -------------
# topic 5: game, season, run, food, hit, win, james, second, yankee, team, leave, mets, go, good, lead
# -------------
# topic 6: percent, market, olympic, rate, point, investor, stock, feed, price, rise, summer, fall, company, energy, bank
# -------------
# topic 7: united, company, game, american, team, world, country, official, attack, play, group, player, russian, deal, city
# -------------
# topic 8: work, art, world, go, want, thing, million, sell, fashion, im, way, look, think, day, wear
# -------------
# topic 9: child, health, american, general, investigation, agency, professor, week, federal, broadway, company, show, musical, statement, disease
# -------------
# topic 10: court, police, go, case, york, law, gay, woman, rule, work, justice, house, bar, officer, pay
# -------------

# %% [markdown]
# ### Wordclouds of most likely words in each topic

# %% [markdown]
# #### Obtain a topic collection for visualizing topics more clearly
# We convert the topic description from spark to a collection represented by `[topic_number, [(word, weight)]]`. This makes it easy to visualize as a wordcloud based on topic

# %%
topic_collection = []
for i, words in enumerate(topic_words):
    word_weights = list(zip(words, topic_weights[i]))
    topic_collection.append((i, word_weights))

# %%
def plot_wordclouds(topics):
    cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
    cloud = WordCloud(background_color='white',
                      width=1000,
                      height=800,
                      colormap='cividis',
                     )
    # Define the size of the subplot matrix as a function of num_topics
    dim = ceil(sqrt(len(topics)))
    fig = plt.figure(figsize=(15, 15))
    
    for i in range(len(topics)):
        print("Topic {}".format(i+1))
        ax = fig.add_subplot(dim, dim, i+1) 
        topic_words = dict(topics[i][1])
        wordcloud = cloud.generate_from_frequencies(topic_words)
        ax.imshow(wordcloud)
        ax.set_title('Topic {}'.format(i+1))
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        ax.tick_params(length=0)

    plt.subplots_adjust(wspace=0, hspace=0);
    plt.margins(x=0, y=0);
    plt.tight_layout();

# %%
plot_wordclouds(topic_collection)
# Out:
# Topic 1
# Topic 2
# Topic 3
# Topic 4
# Topic 5
# Topic 6
# Topic 7
# Topic 8
# Topic 9
# Topic 10
